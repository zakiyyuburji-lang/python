# %%
d = "Dog "
print(d.strip())
# Out:
# Dog

# %%
print(d.lower().strip())
# Out:
# dog

# %%
bag = ["pen", "book", "eraser", "computer", "wallet", "pencil", "water_bottle"]
print(bag)
# Out:
# ['pen', 'book', 'eraser', 'computer', 'wallet', 'pencil', 'water_bottle']

# %%
print("number of items in the bag is:", len(bag))
# Out:
# number of items in the bag is: 7

# %%
first_item = bag[0]
middle_item = bag[3]
last_item = bag[6]
print("the first, middle and last item in the list are:".title(), first_item + "," " " + middle_item + "," " "  + "and" + " "  + last_item + " " "respectively")
# Out:
# The First, Middle And Last Item In The List Are: pen, computer, and water_bottle respectively

# %% [markdown]
# 5. Mix Data

# %%
mix_data = ['Aliyu', "67", "Galadima", "Buhari_India", "1001", "01", "Burji", "Gimawa", "Shagari_quarters"]
print(mix_data)
# Out:
# ['Aliyu', '67', 'Galadima', 'Buhari_India', '1001', '01', 'Burji', 'Gimawa', 'Shagari_quarters']

# %% [markdown]
# 6.7. Companies

# %%
companies = ["Facebook", "Google", "microsof", "Apple", "IBM"]
print(companies)
# Out:
# ['Facebook', 'Google', 'microsof', 'Apple', 'IBM']

# %% [markdown]
# 8. length of the companies

# %%
print("numaber of companies is:", len(companies))
# Out:
# numaber of companies is: 5

# %% [markdown]
# 9. First, Middle and Last company

# %%
print("the first, middle and the last company are:",companies[0],"," "", companies[2],  "and",  companies[4], "respectively.")
# Out:
# the first, middle and the last company are: Facebook , microsof and IBM respectively.

# %% [markdown]
#  10. modifying IBm company

# %%
companies[4] = "Grand dynamic ltd"
print("the updated list of the company is:", companies)
# Out:
# the updated list of the company is: ['Facebook', 'Google', 'microsof', 'Apple', 'Grand dynamic ltd']

# %% [markdown]
# 11. Adding company

# %%
companies.append("iche_tech Kano")
print(companies)
# Out:
# ['Facebook', 'Google', 'microsof', 'Apple', 'Grand dynamic ltd', 'iche_tech Kano']

# %% [markdown]
# 12. insert IT company in the middle

# %%
companies.insert(3, "Zakiyyu and Co")
print(companies)
# Out:
# ['Facebook', 'Google', 'Zakiyyu and Co.', 'Zakiyyu and Co', 'iche_tech Kano', 'microsof', 'Apple', 'Grand dynamic ltd', 'iche_tech Kano']
