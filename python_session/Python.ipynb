# %%
x = 3
y = 6
print("sum", x+y)
# Out:
# sum 9

# %%
name = "abubakar"
print(name.upper())
# Out:
# ABUBAKAR

# %%
print(name.title())
# Out:
# Abubakar

# %%
a = "1234"
b = "56789" 
print(a+b)
# Out:
# 123456789

# %%
first_name = "zakiyyu"
last_name = "suleiman"
full_name = first_name + " " + last_name
print(full_name.title())
# Out:
# Zakiyyu Suleiman

# %%
a = "Hello world!"
print(a.title())
# Out:
# Hello World!

# %%
print(a.capitalize())
# Out:
# Hello world!

# %%
name = "sunusi "
name2 = name.title().strip()
print(name2)
# Out:
# Sunusi

# %%
name = "zakiyye "
print(name.replace("e","u").title().strip())
# Out:
# Zakiyyu
